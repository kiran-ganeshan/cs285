# %%
import matplotlib.pyplot as plt
# %matplotlib inline
step = [100, 200, 500, 1000, 2000, 5000, 10000]
avgs = [-390.78, 401.1, 3845.3, 4482.2, 4589.0, 4708.7, 4684.0]
stds = [581.6, 371.8, 370.9, 137.3, 79.6, 128.0, 120.4]
plt.errorbar(step, avgs, stds)
plt.xscale('log')
plt.xlabel('num gradient steps per epoch')
plt.ylabel('Average Return')
plt.show()

# %%
steps = list(range(10))
ant_avgs = [4482, 4615, 4603, 4633, 4679, 3770, 4672, 4634, 4672, 4695]
ant_stds = [137, 136, 145, 84, 40, 1473, 104, 115, 94, 103]
hopper_avgs = [888, 834, 2237, 2883, 3224, 2411, 3708, 3696, 3534, 3523]
hopper_stds = [100, 53, 551, 828, 733, 889, 5, 93, 438, 453]
plt.errorbar(steps, ant_avgs, ant_stds, label='Ant-v4')
plt.errorbar(steps[:len(hopper_avgs)], hopper_avgs, hopper_stds, label='Hopper-v4')
plt.xlabel('Epoch')
plt.ylabel('Return')
plt.legend()
plt.show()
